# %% [markdown]
# # Read the Comma Seperated File using Pandas Library.
# #### In this cell, I have imported panda library as pd.Read the csv with the method called 'read_csv'.Created a data frame named as 'data' which consist of all the schema and content of the file.

# %%
import pandas as pd
data=pd.read_csv("C:\\Users\\nex4vgv\\Documents\\SampleSuperstoree.csv",header=0)
data

# %% [markdown]
# # Group By the column here.
# #### In this cell, There is column called 'Ship Mode' in the csv so I have performed a group by(also known as Distinct,Unique).Similarly on the same cell I have performed the mean function on the major columns like Quantity,Discount,Profit with respect to Unique Ship Mode.

# %%
ShipMode=data.groupby('Ship Mode')
ShipMode.mean()
# Out:
#                      Row ID   Postal Code       Sales  Quantity  Discount  \
# Ship Mode
# First Class     4875.510403  54765.611834  228.497024  3.701560  0.164610
# Same Day        5128.909761  57536.082873  236.396179  3.609576  0.152394
# Second Class    4936.759383  55626.009254  236.089239  3.816452  0.138895
# Standard Class  5036.776977  54944.447051  227.583067  3.819873  0.160023
#
#                    Profit
# Ship Mode
# First Class     31.839948
# Same Day        29.266591
# Second Class    29.535545
# Standard Class  27.494770

# %%
OrderID=data['Order ID'].value_counts()
OrderID
# Out:
# CA-2014-100111    14
# CA-2014-157987    12
# US-2013-108504    11
# CA-2013-165330    11
# CA-2012-131338    10
# CA-2013-105732    10
# US-2012-126977    10
# CA-2012-164882     9
# CA-2013-145177     9
# CA-2012-158421     9
# US-2012-163433     9
# CA-2012-132626     9
# CA-2014-140949     9
# CA-2012-104346     9
# CA-2011-106439     9
# US-2013-114013     9
# CA-2014-117457     9
# CA-2011-129364     8
# CA-2011-142769     8
# CA-2014-110905     8
# CA-2014-113278     8
# US-2013-110156     8
# CA-2014-140872     8
# CA-2014-118017     8
# CA-2011-167927     8
# CA-2014-156776     8
# CA-2012-167010     8
# CA-2014-161956     8
# CA-2014-102925     8
# US-2014-118087     8
#                   ..
# CA-2013-118969     1
# CA-2012-134719     1
# US-2011-143581     1
# CA-2012-131597     1
# CA-2013-166429     1
# CA-2011-132801     1
# CA-2013-108644     1
# CA-2012-166604     1
# CA-2014-106782     1
# CA-2013-108959     1
# CA-2012-112557     1
# US-2014-157896     1
# ...

# %% [markdown]
# # Again read the data using panda library.

# %%
import pandas as pd
df=pd.read_csv("C:\\Users\\nex4vgv\\Documents\\SampleSuperstoree.csv",header=0)
df
# Out:
#       Row ID        Order ID  Order Date   Ship Date       Ship Mode  \
# 0       7981  CA-2011-103800    1/3/2013    1/7/2013  Standard Class
# 1        740  CA-2011-112326    1/4/2013    1/8/2013  Standard Class
# 2        741  CA-2011-112326    1/4/2013    1/8/2013  Standard Class
# 3        742  CA-2011-112326    1/4/2013    1/8/2013  Standard Class
# 4       1760  CA-2011-141817    1/5/2013   1/12/2013  Standard Class
# 5       5328  CA-2011-130813    1/6/2013    1/8/2013    Second Class
# 6       7181  CA-2011-106054    1/6/2013    1/7/2013     First Class
# 7       7475  CA-2011-167199    1/6/2013   1/10/2013  Standard Class
# 8       7476  CA-2011-167199    1/6/2013   1/10/2013  Standard Class
# 9       7477  CA-2011-167199    1/6/2013   1/10/2013  Standard Class
# 10      7478  CA-2011-167199    1/6/2013   1/10/2013  Standard Class
# 11      7479  CA-2011-167199    1/6/2013   1/10/2013  Standard Class
# 12      7480  CA-2011-167199    1/6/2013   1/10/2013  Standard Class
# ...

# %% [markdown]
# # Percentage on the basis of the unique quantity.
# ### In this cell, the 'value_counts' plays a major role to find out the not null values and find the percentage with respect to the group by column which is 'Quantity' here.
# #### The SQL query will be more helpful to understand the current cell - select (Quantity),(Count(OrderID)/9994*100) as Score from friends.sampledatapanda group by 1

# %%
value=df['Quantity'].value_counts(normalize=True)
value
# Out:
# 3     0.241045
# 2     0.240344
# 5     0.123074
# 4     0.119172
# 1     0.089954
# 7     0.060636
# 6     0.057234
# 9     0.025815
# 8     0.025715
# 10    0.005703
# 11    0.003402
# 14    0.002902
# 13    0.002702
# 12    0.002301
# Name: Quantity, dtype: float64
